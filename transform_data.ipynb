# %%
import pandas as pd

# %%
ev_df = pd.read_csv('Resources/electric_reg_by_state.csv')
fuel_prices = pd.read_csv('Resources/fuel_prices_by_state.csv')
population = pd.read_csv('Resources/population.csv')
income = pd.read_csv('Resources/income.csv')

# %% [markdown]
# ## Make a primary key

# %%
def create_id(file):
    file['id'] = ""
    for x in range(50):
        file['id'][x] = x+1
    return file

# %%
create_id(population)
create_id(fuel_prices)
create_id(ev_df)
create_id(income)
# Out:
# /Users/sreeven/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#              state  income  id
# 0          Alabama   48486   1
# 1           Alaska   76715   2
# 2          Arizona   56213   3
# 3         Arkansas   45726   4
# 4       California   71228   5
# 5         Colorado   68811   6
# 6      Connecticut   76106   7
# 7         Delaware   65627   8
# 8          Florida   53267   9
# 9          Georgia   55679  10
# 10          Hawaii   78084  11
# 11           Idaho   53089  12
# 12        Illinois   63575  13
# 13         Indiana   54325  14
# 14            Iowa   58580  15
# 15          Kansas   57422  16
# 16        Kentucky   48392  17
# 17       Louisiana   47942  18
# 18           Maine   55425  19
# 19        Maryland   81868  20
# 20   Massachusetts   77378  21
# 21        Michigan   54938  22
# 22       Minnesota   68411  23
# 23     Mississippi   43567  24
# 24        Missouri   53560  25
# 25         Montana   52559  26
# 26        Nebraska   59116  27
# 27          Nevada   57598  28
# 28   New Hampshire   74057  29
# 29      New Jersey   79363  30
# 30      New Mexico   48059  31
# 31        New York   65323  32
# 32  North Carolina   52413  33
# 33    North Dakota   63473  34
# 34            Ohio   54533  35
# 35        Oklahoma   51424  36
# 36          Oregon   59393  37
# 37    Pennsylvania   59445  38
# 38    Rhode Island   63296  39
# 39  South Carolina   51015  40
# 40    South Dakota   56499  41
# 41       Tennessee   50972  42
# 42           Texas   59570  43
# 43            Utah   68374  44
# 44         Vermont   60076  45
# 45        Virginia   71564  46
# 46      Washington   70116  47
# 47   West Virginia   44921  48
# 48       Wisconsin   59209  49
# 49         Wyoming   62268  50

# %% [markdown]
# ## Check if states match

# %%
def matching(file_1, file_2, file_3, file_4):
    for x in range(50):
        if file_1['id'][x] == file_2['id'][x] == file_3['id'][x] == file_4['id'][x]:
            print('Matching')
        else:
            print(f"Error: {x} {file_1['id'][x]}")

# %%
matching(fuel_prices, ev_df, population, income)
# Out:
# Matching
# Matching
# Matching
# Matching
# Matching
# Matching
# Matching
# Matching
# Matching
# Matching
# Matching
# Matching
# Matching
# Matching
# Matching
# Matching
# Matching
# Matching
# Matching
# Matching
# Matching
# Matching
# Matching
# Matching
# Matching
# Matching
# Matching
# Matching
# Matching
# Matching
# Matching
# Matching
# Matching
# Matching
# Matching
# Matching
# Matching
# Matching
# Matching
# Matching
# Matching
# Matching
# Matching
# Matching
# Matching
# Matching
# Matching
# Matching
# Matching
# Matching

# %% [markdown]
# ## Create state id table

# %%
states = pd.DataFrame({'id':ev_df['id'],
                     'state':ev_df['state']})

# %%
def convert_to_int (file):
    file['id'] = file['id'].astype(int)
    return file

# %%
ev_df.dtypes
# Out:
# state            object
# registrations     int64
# id               object
# dtype: object

# %%
convert_to_int(ev_df)
convert_to_int(population)
convert_to_int(income)
convert_to_int(states)
convert_to_int(fuel_prices)
# Out:
#              state  regular  mid_grade  premium  diesel  id
# 0          Alabama     1.89       2.23     2.55    2.27   1
# 1           Alaska     2.49       2.63     2.80    2.50   2
# 2          Arizona     2.22       2.50     2.75    2.43   3
# 3         Arkansas     1.86       2.15     2.45    2.19   4
# 4       California     3.19       3.37     3.49    3.38   5
# 5         Colorado     2.19       2.50     2.79    2.26   6
# 6      Connecticut     2.16       2.51     2.73    2.65   7
# 7         Delaware     2.36       2.73     2.93    2.49   8
# 8          Florida     2.15       2.49     2.78    2.37   9
# 9          Georgia     1.98       2.32     2.62    2.42  10
# 10          Hawaii     3.27       3.45     3.68    4.07  11
# 11           Idaho     2.29       2.45     2.64    2.66  12
# 12        Illinois     2.25       2.59     2.99    2.45  13
# 13         Indiana     2.06       2.35     2.67    2.49  14
# 14            Iowa     2.01       2.16     2.55    2.27  15
# 15          Kansas     1.91       2.16     2.39    2.19  16
# 16        Kentucky     2.01       2.30     2.60    2.27  17
# 17       Louisiana     1.87       2.20     2.50    2.22  18
# 18           Maine     2.16       2.48     2.74    2.49  19
# 19        Maryland     2.33       2.76     2.98    2.62  20
# 20   Massachusetts     2.10       2.45     2.66    2.53  21
# 21        Michigan     2.06       2.34     2.67    2.40  22
# 22       Minnesota     1.97       2.21     2.51    2.36  23
# 23     Mississippi     1.83       2.14     2.47    2.10  24
# 24        Missouri     1.80       2.05     2.31    2.05  25
# 25         Montana     2.23       2.49     2.75    2.38  26
# 26        Nebraska     2.09       2.20     2.52    2.26  27
# 27          Nevada     2.59       2.81     2.98    2.64  28
# 28   New Hampshire     2.06       2.44     2.70    2.44  29
# 29      New Jersey     2.29       2.67     2.84    2.56  30
# 30      New Mexico     2.01       2.32     2.58    2.32  31
# 31        New York     2.25       2.57     2.80    2.77  32
# 32  North Carolina     2.00       2.34     2.67    2.35  33
# 33    North Dakota     2.01       2.22     2.43    2.35  34
# 34            Ohio     2.06       2.35     2.68    2.42  35
# 35        Oklahoma     1.85       2.09     2.31    2.07  36
# 36          Oregon     2.59       2.78     2.96    2.73  37
# 37    Pennsylvania     2.54       2.86     3.12    2.79  38
# 38    Rhode Island     2.11       2.51     2.73    2.57  39
# 39  South Carolina     1.91       2.25     2.57    2.19  40
# 40    South Dakota     2.11       2.21     2.56    2.30  41
# 41       Tennessee     1.90       2.23     2.56    2.31  42
# 42           Texas     1.84       2.16     2.44    2.06  43
# 43            Utah     2.28       2.45     2.61    2.67  44
# 44         Vermont     2.14       2.46     2.75    2.49  45
# 45        Virginia     2.08       2.47     2.76    2.36  46
# 46      Washington     2.76       2.97     3.13    2.84  47
# 47   West Virginia     2.16       2.45     2.74    2.44  48
# 48       Wisconsin     1.91       2.25     2.63    2.25  49
# 49         Wyoming     2.20       2.42     2.66    2.47  50

# %%
fuel_prices.dtypes
# Out:
# state         object
# regular      float64
# mid_grade    float64
# premium      float64
# diesel       float64
# id             int64
# dtype: object

# %% [markdown]
# ## Set Index

# %%
ev_df = ev_df.set_index('id')
fuel_prices = fuel_prices.set_index('id')
states = states.set_index('id')
population = population.set_index('id')
income = income.set_index('id')

# %% [markdown]
# ## Export

# %%
ev_df.to_csv('clean_data/ev_registrations.csv')
fuel_prices.to_csv('clean_data/fuel_prices_2020.csv')
states.to_csv('clean_data/states.csv')
population.to_csv('clean_data/population.csv')
income.to_csv('clean_data/income.csv')

# %% [markdown]
# ## Load to SQL

# %%
from sqlalchemy import create_engine

# %%
connection_string = "postgres:4657@localhost:5433/2020_state_info"
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine.table_names()
# Out:
# ['states', 'ev_registrations', 'fuel_prices', 'population', 'income']

# %%
states.to_sql(name='states', con=engine, if_exists='append', index=True)

# %%
ev_df.to_sql(name='ev_registrations', con=engine, if_exists='append', index=True)

# %%
fuel_prices.to_sql(name='fuel_prices', con=engine, if_exists='append', index=True)

# %%
population.to_sql(name='population', con=engine, if_exists='append', index=True)

# %%
income.to_sql(name='income', con=engine, if_exists='append', index=True)
